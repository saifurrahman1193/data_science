# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string

# %%
# Download necessary NLTK datasets
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Sample text
text = "Natural $ Language Processing (NLP) is a fascinating field. It involves understanding and generating human language!"
text
# Out:
# 'Natural $ Language Processing (NLP) is a fascinating field. It involves understanding and generating human language!'

# %%
# 1. Convert text to lowercase
text = text.lower()
text
# Out:
# 'natural $ language processing (nlp) is a fascinating field. it involves understanding and generating human language!'

# %%
# 2. Remove punctuation, special characters
text = text.translate(str.maketrans('', '', string.punctuation))
text
# Out:
# 'natural  language processing nlp is a fascinating field it involves understanding and generating human language'

# %%
# 3. Tokenize text
tokens = word_tokenize(text)
tokens
# Out:
# ['natural',
#  'language',
#  'processing',
#  'nlp',
#  'is',
#  'a',
#  'fascinating',
#  'field',
#  'it',
#  'involves',
#  'understanding',
#  'and',
#  'generating',
#  'human',
#  'language']

# %%
# 4. Remove stop words
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]
# filtered_tokens = []
# for word in tokens:
#     if word not in stop_words:
#         filtered_tokens.append(word)
filtered_tokens
# Out:
# ['natural',
#  'language',
#  'processing',
#  'nlp',
#  'fascinating',
#  'field',
#  'involves',
#  'understanding',
#  'generating',
#  'human',
#  'language']

# %%
# 5. Lemmatize tokens
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
# lemmatized_tokens = []  # Create an empty list to store results
# for word in filtered_tokens:  # Loop through each word in filtered_tokens
#     lemma = lemmatizer.lemmatize(word)  # Apply lemmatization to the word
#     lemmatized_tokens.append(lemma)  # Add the lemmatized word to the list

# %%
# Final processed text
processed_text = ' '.join(lemmatized_tokens)

print("Original Text:")
print(text)
print("\nProcessed Text:")
print(processed_text)
# Out:
# Original Text:
# natural language processing nlp is a fascinating field it involves understanding and generating human language
#
# Processed Text:
# natural language processing nlp fascinating field involves understanding generating human language
