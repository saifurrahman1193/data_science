# %%
# 📂 Importing Pandas

# %%
import pandas as pd

# %%
# Creating DataFrames
# 1️⃣ From a Dictionary

data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'City': ['NY', 'LA', 'SF']}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age City
# 0    Alice   25   NY
# 1      Bob   30   LA
# 2  Charlie   35   SF

# %%
# From a CSV File
df = pd.read_csv("./data.csv")  # Load CSV into a DataFrame

# %%
# 3️⃣ From an Excel File

df = pd.read_excel('data.xlsx')

# %%
# 🔍 Exploring Data

df.head()  # First 5 rows
# Out:
#       Name  Age     City
# 0    Alice   25       NY
# 1      Bob   30       LA
# 2  Charlie   35       SF
# 3    David   28  Chicago
# 4      Eve   40    Miami

# %%
df.tail()  # Last 5 rows
# Out:
#       Name  Age     City
# 0    Alice   25       NY
# 1      Bob   30       LA
# 2  Charlie   35       SF
# 3    David   28  Chicago
# 4      Eve   40    Miami

# %%
df.info()  # Summary of DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %%
df.describe()  # Summary statistics
# Out:
#             Age
# count   5.00000
# mean   31.60000
# std     5.94138
# min    25.00000
# 25%    28.00000
# 50%    30.00000
# 75%    35.00000
# max    40.00000

# %%
df.shape  # (rows, columns)
# Out:
# (5, 3)

# %%
df.columns  # List of column names
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df.dtypes  # Data types of each column
# Out:
# Name    object
# Age      int64
# City    object
# dtype: object

# %%
# 🎯 Selecting Data

# %%
# 1️⃣ Selecting Columns

# %%
df['Name']  # Single column (Series)
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4        Eve
# Name: Name, dtype: object

# %%
df[['Name', 'Age']]  # selecting/Filtering Multiple columns (DataFrame)
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   28
# 4      Eve   40

# %%
# 2️⃣ Selecting Rows (Indexing)

# %%
df.iloc[0]  # First row (by position)
# Out:
# Name    Alice
# Age        25
# City       NY
# Name: 0, dtype: object

# %%
df.loc[0]  # First row (by label)
# Out:
# Name    Alice
# Age        25
# City       NY
# Name: 0, dtype: object

# %%
df.loc[1:2, ['Name', 'Age']]  # Specific rows & columns
# Out:
#       Name  Age
# 1      Bob   30
# 2  Charlie   35

# %%
# 3️⃣ Filtering Data

df[df['Age'] > 25]  # Filter rows where Age > 25
# Out:
#       Name  Age     City
# 1      Bob   30       LA
# 2  Charlie   35       SF
# 3    David   28  Chicago
# 4      Eve   40    Miami

# %%
df[df['City'] == 'NY']  # Filter rows where City = 'NY'
# Out:
#     Name  Age City
# 0  Alice   25   NY

# %%
# 🛠️ Modifying Data

# %%
# 1️⃣ Adding/Inserting a Column

# %%
df['Salary'] = [50000, 60000, 70000, 80000, 90000]

# %%
# 2️⃣ Updating Values

df.loc[0, 'Age'] = 26  # Update a specific value

# %%
df['Age'] = df['Age'] + 1  # Increment all ages by 1

# %%
# 3️⃣ Removing Columns

df.drop(columns=['Salary'], inplace=True)

# %%
# 4️⃣ Removing Rows

df.drop(index=1, inplace=True)  # Remove row with index 1

# %%
# 📌 Sorting & Grouping
# 1️⃣ Sorting Data
df.sort_values(by='Age', ascending=False)

# %%
# 2️⃣ Grouping Data

df.groupby('City')['Age'].mean()  # Average age per city

# %%
# 📈 Working with Missing Data

df.isnull().sum()  # Check missing values
df.fillna(0, inplace=True)  # Replace missing values with 0
df.dropna(inplace=True)  # Remove rows with missing values

# %%
# 📤 Exporting Data

df.to_csv('output.csv', index=False)
df.to_excel('output.xlsx', index=False)
