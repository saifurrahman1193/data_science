# %%
import pandas as pd
reviews = pd.read_excel("./reviews.xlsx")
pd.set_option('display.max_rows', 5)

# %%
# reviews: Refers to the Pandas DataFrame containing your data.
# price: Specifies the column you're interested in.
# .dtype: This attribute returns the data type of the specified column.

reviews.price.dtype
# Out:
# dtype('float64')

# %%
# reviews: Refers to the Pandas DataFrame containing your data.
# .dtypes: This attribute returns a Pandas Series where the index is the column names, and the values are their corresponding data types.
    
reviews.dtypes
# Out:
# country        object
# description    object
#                 ...
# variety        object
# winery         object
# Length: 13, dtype: object

# %%
# reviews: This is the DataFrame containing your data.
# reviews.country: This selects the country column from the reviews DataFrame.
# pd.isnull(reviews.country): This applies the pd.isnull() function to the country column, returning a Series of boolean values where True indicates the presence of a NaN value.
# reviews[pd.isnull(reviews.country)]: This uses boolean indexing to filter the reviews DataFrame, returning only the rows where the country column is NaN.
# or reviews[reviews['country'].isna()]

reviews[pd.isnull(reviews.country)]
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %%
# reviews.region_2: This part refers to the 'region_2' column within the 'reviews' DataFrame.
# .fillna("Unknown"): This method replaces any missing values (NaN, Null) in the 'region_2' column with the string "Unknown".

# or reviews.region_2.where(reviews.region_2.notna(), "Unknown")
# or reviews['region_2'].fillna('Unknown')

reviews.region_2.fillna("Unknown")
# Out:
# 0     Unknown
# 1     Unknown
#        ...
# 14    Unknown
# 15    Unknown
# Name: region_2, Length: 16, dtype: object

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0        @kerino
# 1     @vossroger
#          ...
# 14    @vossroger
# 15    @vossroger
# Name: taster_twitter_handle, Length: 16, dtype: object
