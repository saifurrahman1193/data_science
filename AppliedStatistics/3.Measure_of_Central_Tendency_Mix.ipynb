# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame(ages, columns=['age'])
df.head()
# Out:
#    age
# 0   21
# 1   25
# 2   19
# 3   19
# 4   25

# %%
df.age.mean()
# Out:
# 22.88888888888889

# %%
df.age.median()
# Out:
# 24.0

# %%
df.age.mode()
# Out:
# 0    19
# 1    24
# 2    25
# Name: age, dtype: int64
